# %%
from matplotlib import pyplot as plt
import numpy as np

import json
import os, sys
from os.path import join

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from config import DATA_PATH

plt.rcdefaults() 
# %matplotlib inline

INPUT_PATH = join(DATA_PATH, "classifiers/mnist/")
CLASSIFIERS = ["resnet/relu", "resnet/brelu", "cnn/relu", "cnn/relu/labsmooth", "cnn/brelu", "cnn/relu/gaussian/stdev0.30/pert-insts10", "cnn/brelu/gaussian/stdev0.30/pert-insts10"]
               
accuracies = {}
for c in CLASSIFIERS:
    with open(join(INPUT_PATH, c, "accuracies.json"), "r") as json_file:
        accuracies[c] = json.load(json_file)

# %%
DATASET = "/dccstor/dlw/data/adversarial_learning/adversarial/mnist/cnn/relu/fgsm"
print("Accuracy on black-box attacks on", DATASET)

train, test = {}, {}
eps_values = [e/10 for e in range(1, 11)]

for c in CLASSIFIERS:
    train[c] = [accuracies[c]["train_accuracy"]]
    test[c] = [accuracies[c]["test_accuracy"]]

    for eps in eps_values:
        train[c].append(accuracies[c][join(DATASET, "eps%.2f_train.npy" % eps)])
        test[c].append(accuracies[c][join(DATASET,"eps%.2f_test.npy" % eps)])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
plt.title("Train Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, train[c], label=c)

ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
plt.legend()

ax = fig.add_subplot(1, 2, 2)
plt.title("Test Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, test[c], label=c)
    
ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
    
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.legend()
# Out:
# Accuracy on black-box attacks on /dccstor/dlw/data/adversarial_learning/adversarial/mnist/cnn/relu/fgsm

# %% [markdown]
# As expected, the classifier used for crafting the adversarials is the most vulnerable to the attack.
#
# **cnn/relu/gaussian/** is still the best model, even if it has the same architecture as the classifier used for crafting.
#
# Need to:
# 1. compare different std dev and nb perturbed instances
# 2. gaussian with brelu

# %%
DATASET = "/dccstor/dlw/data/adversarial_learning/adversarial/mnist/cnn/brelu/fgsm"
print("Accuracy on black-box attacks on", DATASET)

train, test = {}, {}
eps_values = [e/10 for e in range(1, 11)]

for c in CLASSIFIERS:
    train[c] = [accuracies[c]["train_accuracy"]]
    test[c] = [accuracies[c]["test_accuracy"]]

    for eps in eps_values:
        train[c].append(accuracies[c][join(DATASET, "eps%.2f_train.npy" % eps)])
        test[c].append(accuracies[c][join(DATASET,"eps%.2f_test.npy" % eps)])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
plt.title("Train Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, train[c], label=c)

ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
plt.legend()

ax = fig.add_subplot(1, 2, 2)
plt.title("Test Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, test[c], label=c)
    
ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
    
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.legend()
# Out:
# Accuracy on black-box attacks on /dccstor/dlw/data/adversarial_learning/adversarial/mnist/cnn/brelu/fgsm

# %%
DATASET = "/dccstor/dlw/data/adversarial_learning/adversarial/mnist/resnet/relu/fgsm"
print("Accuracy on black-box attacks on", DATASET)

train, test = {}, {}
eps_values = [e/10 for e in range(1, 11)]

for c in CLASSIFIERS:
    train[c] = [accuracies[c]["train_accuracy"]]
    test[c] = [accuracies[c]["test_accuracy"]]

    for eps in eps_values:
        train[c].append(accuracies[c][join(DATASET, "eps%.2f_train.npy" % eps)])
        test[c].append(accuracies[c][join(DATASET,"eps%.2f_test.npy" % eps)])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
plt.title("Train Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, train[c], label=c)

ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
plt.legend()

ax = fig.add_subplot(1, 2, 2)
plt.title("Test Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, test[c], label=c)
    
ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
    
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.legend()
# Out:
# Accuracy on black-box attacks on /dccstor/dlw/data/adversarial_learning/adversarial/mnist/resnet/relu/fgsm

# %%
DATASET = "/dccstor/dlw/data/adversarial_learning/adversarial/mnist/resnet/brelu/fgsm"
print("Accuracy on black-box attacks on", DATASET)

train, test = {}, {}
eps_values = [e/10 for e in range(1, 11)]

for c in CLASSIFIERS:
    train[c] = [accuracies[c]["train_accuracy"]]
    test[c] = [accuracies[c]["test_accuracy"]]

    for eps in eps_values:
        train[c].append(accuracies[c][join(DATASET, "eps%.2f_train.npy" % eps)])
        test[c].append(accuracies[c][join(DATASET,"eps%.2f_test.npy" % eps)])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
plt.title("Train Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, train[c], label=c)

ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
plt.legend()

ax = fig.add_subplot(1, 2, 2)
plt.title("Test Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, test[c], label=c)
    
ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
    
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.legend()
# Out:
# Accuracy on black-box attacks on /dccstor/dlw/data/adversarial_learning/adversarial/mnist/resnet/brelu/fgsm

# %%
DATASET = "/dccstor/dlw/data/adversarial_learning/adversarial/mnist/cnn/relu/gaussian/stdev0.30/pert-insts10/fgsm"
print("Accuracy on black-box attacks on", DATASET)

train, test = {}, {}
eps_values = [e/10 for e in range(1, 11)]

for c in CLASSIFIERS:
    train[c] = [accuracies[c]["train_accuracy"]]
    test[c] = [accuracies[c]["test_accuracy"]]

    for eps in eps_values:
        train[c].append(accuracies[c][join(DATASET, "eps%.2f_train.npy" % eps)])
        test[c].append(accuracies[c][join(DATASET,"eps%.2f_test.npy" % eps)])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
plt.title("Train Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, train[c], label=c)

ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
plt.legend()

ax = fig.add_subplot(1, 2, 2)
plt.title("Test Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, test[c], label=c)
    
ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
    
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.legend()
# Out:
# Accuracy on black-box attacks on /dccstor/dlw/data/adversarial_learning/adversarial/mnist/cnn/relu/gaussian/stdev0.30/pert-insts10/fgsm

# %% [markdown]
# Even on its own adversarials, **gaussian** doesn't significantly act worse than the other models.
#
# Need to:
# 1. try with more points
# 2. find a way to learn on distributions

# %%
DATASET = "/dccstor/dlw/data/adversarial_learning/adversarial/mnist/cnn/brelu/gaussian/stdev0.30/pert-insts10/fgsm"
print("Accuracy on black-box attacks on", DATASET)

train, test = {}, {}
eps_values = [e/10 for e in range(1, 11)]

for c in CLASSIFIERS:
    train[c] = [accuracies[c]["train_accuracy"]]
    test[c] = [accuracies[c]["test_accuracy"]]

    for eps in eps_values:
        train[c].append(accuracies[c][join(DATASET, "eps%.2f_train.npy" % eps)])
        test[c].append(accuracies[c][join(DATASET,"eps%.2f_test.npy" % eps)])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
plt.title("Train Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, train[c], label=c)

ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
plt.legend()

ax = fig.add_subplot(1, 2, 2)
plt.title("Test Accuracies")

for c in CLASSIFIERS:
    plt.plot([0.] + eps_values, test[c], label=c)
    
ax.set_xlim([0, 1])
ax.set_ylim([0, 100])
plt.xlabel("epsilon")
plt.ylabel("accuracy (%)")
    
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.legend()
# Out:
# Accuracy on black-box attacks on /dccstor/dlw/data/adversarial_learning/adversarial/mnist/cnn/brelu/gaussian/stdev0.30/pert-insts10/fgsm
